# %%
import pandas as pd
import configparser
import os

# Read the value from the config.ini file
config = configparser.ConfigParser()
config.read('config.ini')
output_file_dir = config.get('path', 'output_file_dir')
output_file_name_net_sales = config.get('path', 'output_file_name_net_sales')
cateFileDir = config.get('path', 'cateFileDir')
# Read the category file
try:
    df_cate = pd.read_excel(cateFileDir)
except FileNotFoundError as e:
    try:
        df_cate = pd.read_excel(r"/Users/trieupham/Library/CloudStorage/OneDrive-BTMGlobalConsulting/Projects/data xls/DataCate.xlsx")
    except FileNotFoundError as e:
        df_cate = pd.read_excel(r"C:\Users\Trieu.Pham\OneDrive - BTM Global Consulting\Projects\data xls\DataCate.xlsx")
# using os.path.join() method
# output_file_dir = os.path.join(output_file_dir, 'outputFile')
net_sales_data = os.path.join(output_file_dir, output_file_name_net_sales) + '.csv'
# Read the csv file
# input_file should be the path to the merge csv file
try:
    input_file = net_sales_data
    df = pd.read_csv(input_file)
except FileNotFoundError as e:
    try:
        # Using the path to the csv file for mac os
        input_file = r"/Users/trieupham/Library/CloudStorage/OneDrive-BTMGlobalConsulting/Projects/data csv/outputFile/dataNetsales.csv"
        df = pd.read_csv(input_file)
    except FileNotFoundError as e:
        # Using the path to the csv file for windows
        input_file = r"C:\Users\Trieu.Pham\OneDrive - BTM Global Consulting\Projects\data csv\outputFile\dataNetsales.csv"
        df = pd.read_csv(input_file)
df.dropna(inplace=True)

# %%
df_cate
# Out:
#              Barcode Division Name   Category Name          SubCategory Name  \
# 0      9956991810612   LivingGoods    Living goods  Other Non-edible Grocery
# 1           96183519         Candy  Candy Category                Hard Candy
# 2           96118528         Candy  Candy Category                Hard Candy
# 3           96118511         Candy  Candy Category                Hard Candy
# 4           96118504         Candy  Candy Category                Hard Candy
# ...              ...           ...             ...                       ...
# 13823  8936146730438   Wine&Liquor          Liquor    Cordials/Brandy/Cognac
# 13824  8936146730452   Wine&Liquor          Liquor    Cordials/Brandy/Cognac
# 13825  9322214007387   Wine&Liquor            Wine       Table/Varietal Wine
# 13826  9322214009060   Wine&Liquor            Wine       Table/Varietal Wine
# 13827  9322214011407   Wine&Liquor            Wine       Table/Varietal Wine
#
#                                                Item Name
# 0                              #Alladdin bật lửa x 1 cái
# 1      FISHERMANS Kẹo cay con tàu vị táo quế bạc hà 2...
# 2      FISHERMANS Kẹo cay con tàu vị spearmint 25g x1...
# 3         FISHERMANS Kẹo cay Cherry & Method 25g x 1 gói
# 4                  FISHERMANS Kẹo quýt bạc hà 25g x1 gói
# ...                                                  ...
# 13823    FS WINE Bộ sản phẩm rượu Chivas Regal 18YO 70CL
# 13824  FS WINE Bộ sản phẩm rượu Chivas Regal 18 Mizun...
# 13825      Rượu vang Yellow Tail Chardonnay 750ml x Chai
# 13826           #Rượu vang Yellow Tail Merlot 750mlxchai
# 13827  Rượu vang trắng Yellow Tail  Moscato 750ml x Chai
#
# [13828 rows x 5 columns]

# %%
df_cate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13828 entries, 0 to 13827
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Barcode           13828 non-null  object
#  1   Division Name     13828 non-null  object
#  2   Category Name     13828 non-null  object
#  3   SubCategory Name  13828 non-null  object
#  4   Item Name         13828 non-null  object
# dtypes: object(5)
# memory usage: 540.3+ KB

# %%
df
# Out:
#                 Date      Time           InvoiceID        Barcode  \
# 0         2023-01-01  00:40:59  VN0001010101230001  8935049500544
# 1         2023-01-01  00:41:18  VN0001010101230002  8938512632025
# 2         2023-01-01  00:41:55  VN0001010101230003  8936011773416
# 3         2023-01-01  00:41:55  VN0001010101230003  8936079121761
# 4         2023-01-01  00:41:55  VN0001010101230003  8850453017528
# ...              ...       ...                 ...            ...
# 68978410  2023-07-05  18:58:59  VN0061010507230308  8935250402019
# 68978411  2023-07-05  13:02:59  VN0061010507230185  8934803071085
# 68978412  2023-07-05  09:15:59  VN0061010507230092  8935090910873
# 68978413  2023-07-05  09:15:59  VN0061010507230092  8935005800015
# 68978414  2023-07-05  09:15:59  VN0061010507230092  2120201000017
#
#           Total Include VAT
# 0                    7000.0
# 1                   12000.0
# 2                   25000.0
# 3                   13000.0
# 4                   13000.0
# ...                     ...
# 68978410            48000.0
# 68978411            13000.0
# 68978412            36000.0
# 68978413            12000.0
# 68978414             9000.0
#
# [68978415 rows x 5 columns]

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                 Date      Time           InvoiceID        Barcode  \
# 0         2023-01-01  00:40:59  VN0001010101230001  8935049500544
# 1         2023-01-01  00:41:18  VN0001010101230002  8938512632025
# 2         2023-01-01  00:41:55  VN0001010101230003  8936011773416
# 3         2023-01-01  00:41:55  VN0001010101230003  8936079121761
# 4         2023-01-01  00:41:55  VN0001010101230003  8850453017528
# ...              ...       ...                 ...            ...
# 68978410  2023-07-05  18:58:59  VN0061010507230308  8935250402019
# 68978411  2023-07-05  13:02:59  VN0061010507230185  8934803071085
# 68978412  2023-07-05  09:15:59  VN0061010507230092  8935090910873
# 68978413  2023-07-05  09:15:59  VN0061010507230092  8935005800015
# 68978414  2023-07-05  09:15:59  VN0061010507230092  2120201000017
#
#           Total Include VAT
# 0                    7000.0
# 1                   12000.0
# 2                   25000.0
# 3                   13000.0
# 4                   13000.0
# ...                     ...
# 68978410            48000.0
# 68978411            13000.0
# 68978412            36000.0
# 68978413            12000.0
# 68978414             9000.0
#
# [34840920 rows x 5 columns]

# %%
# # Merge df and df_cate
# df = df.merge(df_cate, on='Barcode', how='left')

# df

# %%
# Add new column StoreID (first 6 digits of InvoiceID)
df['StoreID'] = df['InvoiceID'].str[:6]

# %%
# # Group by InvoiceID and calculate the sum of Total Include VAT for each group
df_grouped = df.groupby('InvoiceID', as_index=False).agg({
    'StoreID': 'first',
    'Date': 'first',
    'Time': 'first',
    'Barcode': 'first',
    'Total Include VAT': 'sum'
})

# %%
from datetime import datetime

# Function to convert time string to a proper time format
def convert_to_time(time_str):
    try:
        return datetime.strptime(time_str, '%H:%M:%S').strftime('%H:%M')
    except ValueError:
        return None

# Function to get Time Range for each Time value
def get_time_range(time_str):
    time_str = convert_to_time(time_str)
    if time_str is None:
        return None
    hour = int(time_str[:2])
    time_range_start = f"{hour:02}:00"
    time_range_end = f"{hour:02}:59"
    return f"{time_range_start}-{time_range_end}"

# Add new column Time Range
df_grouped['Time Range'] = df_grouped['Time'].apply(get_time_range)
df_grouped
# Out:
#                    InvoiceID StoreID        Date      Time        Barcode  \
# 0         VN0001010101230001  VN0001  2023-01-01  00:40:59  8935049500544
# 1         VN0001010101230002  VN0001  2023-01-01  00:41:18  8938512632025
# 2         VN0001010101230003  VN0001  2023-01-01  00:41:55  8936011773416
# 3         VN0001010101230004  VN0001  2023-01-01  00:43:12  8801100128845
# 4         VN0001010101230005  VN0001  2023-01-01  00:44:22  8934588843051
# ...                      ...     ...         ...       ...            ...
# 15597313  VN9996023101230489  VN9996  2023-01-31  23:10:23  8936079121822
# 15597314  VN9996023101230490  VN9996  2023-01-31  23:11:47  8935112200005
# 15597315  VN9996023101230491  VN9996  2023-01-31  23:12:41  2010101000005
# 15597316  VN9996023101230492  VN9996  2023-01-31  23:12:56  8936031835118
# 15597317  VN9996023101230493  VN9996  2023-01-31  23:13:25  8802876204603
#
#           Total Include VAT   Time Range
# 0                    7000.0  00:00-00:59
# 1                   12000.0  00:00-00:59
# 2                  115000.0  00:00-00:59
# 3                  191000.0  00:00-00:59
# 4                   26000.0  00:00-00:59
# ...                     ...          ...
# 15597313           175000.0  23:00-23:59
# 15597314            13000.0  23:00-23:59
# 15597315             3000.0  23:00-23:59
# 15597316            47000.0  23:00-23:59
# 15597317           358000.0  23:00-23:59
#
# [15597318 rows x 7 columns]

# %%
# Create a pivot table to get the matrix representation
pivot_table_total = df_grouped.pivot_table(index=['StoreID','Date'], columns='Time Range', values='Total Include VAT', aggfunc='sum')
pivot_table_total = pivot_table_total.applymap("{:,.0f}".format)

pivot_table_total
# Out:
# Time Range         00:00-00:59 01:00-01:59 02:00-02:59 03:00-03:59  \
# StoreID Date
# VN0001  2023-01-01   3,767,000   4,185,000     728,000     273,000
#         2023-01-02     176,000     356,000     201,000     334,000
#         2023-01-03     496,000     446,000     129,000     106,000
#         2023-01-04     392,000     689,000      86,000         nan
#         2023-01-05     416,000     143,000     224,000     114,000
# ...                        ...         ...         ...         ...
# VN9996  2023-01-28         nan         nan         nan         nan
#         2023-01-29         nan         nan         nan         nan
#         2023-01-30         nan         nan         nan         nan
#         2023-01-31         nan         nan         nan         nan
#         2023-02-01         nan         nan         nan         nan
#
# Time Range         04:00-04:59 05:00-05:59 06:00-06:59 07:00-07:59  \
# StoreID Date
# VN0001  2023-01-01      66,000     126,000     371,000     451,000
#         2023-01-02     218,000      22,000     319,000     393,000
#         2023-01-03      66,000     239,000     539,000   2,179,000
#         2023-01-04      76,000     623,000     467,000   2,745,000
#         2023-01-05     278,000       6,000   1,064,000   2,406,000
# ...                        ...         ...         ...         ...
# VN9996  2023-01-28         nan         nan      82,000     394,000
#         2023-01-29         nan         nan         nan     162,000
#         2023-01-30         nan         nan      82,000     374,000
#         2023-01-31         nan         nan     144,000     117,000
#         2023-02-01         nan         nan         nan     161,000
#
# Time Range         08:00-08:59 09:00-09:59  ... 14:00-14:59 15:00-15:59  \
# StoreID Date                                ...
# VN0001  2023-01-01     243,000     653,000  ...   1,561,000     632,000
#         2023-01-02     569,000     550,000  ...   1,260,000     459,000
#         2023-01-03   3,356,000   1,604,000  ...   1,153,000   2,018,000
#         2023-01-04   3,318,000   2,476,000  ...     935,200   1,903,000
#         2023-01-05   4,623,000   2,333,000  ...   1,825,000   1,648,000
# ...                        ...         ...  ...         ...         ...
# VN9996  2023-01-28   1,147,000     699,000  ...     836,000   2,682,000
#         2023-01-29   1,555,000   1,355,000  ...     695,000   1,648,000
#         2023-01-30     714,000     948,000  ...     503,000   1,039,000
#         2023-01-31     420,000     155,000  ...     319,000     958,000
#         2023-02-01     524,000     656,000  ...     468,000   1,381,000
#
# Time Range         16:00-16:59 17:00-17:59 18:00-18:59 19:00-19:59  \
# StoreID Date
# VN0001  2023-01-01     751,000   1,950,000     794,000     763,000
#         2023-01-02   1,175,000     472,000     343,000     367,000
#         2023-01-03   1,652,000   2,272,000   1,213,000   1,357,000
#         2023-01-04   1,661,000   2,384,000   1,199,300   1,545,000
#         2023-01-05   1,745,000   2,232,000   3,396,000   1,922,000
# ...                        ...         ...         ...         ...
# VN9996  2023-01-28   3,178,000   3,658,000   3,685,000   3,803,000
#         2023-01-29   2,644,000   3,702,000   4,032,000   4,098,000
#         2023-01-30   2,838,000   3,150,000   2,305,000   3,108,000
#         2023-01-31   1,825,000   2,676,000   2,710,000   2,391,000
#         2023-02-01   1,569,000         nan         nan         nan
#
# Time Range         20:00-20:59 21:00-21:59 22:00-22:59 23:00-23:59
# StoreID Date
# VN0001  2023-01-01   1,573,000   1,691,000   2,327,000   1,544,000
#         2023-01-02     848,000   1,173,000   1,012,000     660,000
#         2023-01-03   1,214,000   1,272,000     807,000     363,000
#         2023-01-04     837,000     493,000   1,046,000     966,000
#         2023-01-05   1,196,000   1,579,000   1,624,000     679,000
# ...                        ...         ...         ...         ...
# VN9996  2023-01-28   4,017,000   4,114,000   3,396,000     515,000
#         2023-01-29   3,993,000   3,901,000   2,645,000     173,000
#         2023-01-30   3,444,000   2,847,000   2,847,000     205,000
#         2023-01-31   4,012,000   3,770,000   2,367,000     909,000
#         2023-02-01         nan         nan         nan         nan
#
# [40606 rows x 24 columns]

# %%
# Save the pivot table to csv file
# pivot_table_total.to_csv('TotalPerHour.csv')

# %%
# Create a pivot table to group the data by 'StoreID', 'WeekDay', and 'Time Range'
pivot_table_bill = df_grouped.pivot_table(index=['StoreID', 'Date'], columns='Time Range', values='InvoiceID', aggfunc=pd.Series.nunique, fill_value=0)


# Display the updated DataFrame
pivot_table_bill
# Out:
# Time Range          00:00-00:59  01:00-01:59  02:00-02:59  03:00-03:59  \
# StoreID Date
# VN0001  2023-01-01           65           80           12            7
#         2023-01-02            4            3            4            3
#         2023-01-03            8            5            5            1
#         2023-01-04            8            6            2            0
#         2023-01-05            4            4            2            4
# ...                         ...          ...          ...          ...
# VN9996  2023-01-28            0            0            0            0
#         2023-01-29            0            0            0            0
#         2023-01-30            0            0            0            0
#         2023-01-31            0            0            0            0
#         2023-02-01            0            0            0            0
#
# Time Range          04:00-04:59  05:00-05:59  06:00-06:59  07:00-07:59  \
# StoreID Date
# VN0001  2023-01-01            2            3            9            6
#         2023-01-02            6            2           11           14
#         2023-01-03            2            3           18           78
#         2023-01-04            1           11           18           83
#         2023-01-05            2            1           26           86
# ...                         ...          ...          ...          ...
# VN9996  2023-01-28            0            0            3           13
#         2023-01-29            0            0            0            4
#         2023-01-30            0            0            2           13
#         2023-01-31            0            0            2            5
#         2023-02-01            0            0            0            8
#
# Time Range          08:00-08:59  09:00-09:59  ...  14:00-14:59  15:00-15:59  \
# StoreID Date                                  ...
# VN0001  2023-01-01            9           17  ...           21           15
#         2023-01-02           15            9  ...           20           13
#         2023-01-03           95           54  ...           31           49
#         2023-01-04           99           73  ...           26           42
#         2023-01-05          112           66  ...           37           41
# ...                         ...          ...  ...          ...          ...
# VN9996  2023-01-28           19           15  ...           29           56
#         2023-01-29           44           38  ...           21           44
#         2023-01-30           18           25  ...           11           29
#         2023-01-31           14            5  ...            9           34
#         2023-02-01           15           19  ...           17           26
#
# Time Range          16:00-16:59  17:00-17:59  18:00-18:59  19:00-19:59  \
# StoreID Date
# VN0001  2023-01-01           17           19           24           14
#         2023-01-02           26           11           14           14
#         2023-01-03           41           48           35           28
#         2023-01-04           44           53           28           21
#         2023-01-05           52           33           22           31
# ...                         ...          ...          ...          ...
# VN9996  2023-01-28           74           81           85           97
#         2023-01-29           70           79          101           85
#         2023-01-30           64           83           63           70
#         2023-01-31           48           58           69           64
#         2023-02-01           32            0            0            0
#
# Time Range          20:00-20:59  21:00-21:59  22:00-22:59  23:00-23:59
# StoreID Date
# VN0001  2023-01-01           19           25           23           11
#         2023-01-02           11           18           25           14
#         2023-01-03           25           15           10           10
#         2023-01-04           22           11           20           14
#         2023-01-05           25           18           24           11
# ...                         ...          ...          ...          ...
# VN9996  2023-01-28           84           84           66           13
#         2023-01-29           83           87           59            3
#         2023-01-30           87           59           61            6
#         2023-01-31           80           88           56           12
#         2023-02-01            0            0            0            0
#
# [40606 rows x 24 columns]

# %%
# Save the pivot table to csv file
# pivot_table_bill.to_csv('BillPerHour.csv')

# %%
# Replace non-numeric values (strings) with NaN in pivot_table_total and pivot_table_bill
pivot_table_total_numeric = pivot_table_total.applymap(lambda x: float(x.replace(',', '')) if isinstance(x, str) else np.nan)
pivot_table_bill_numeric = pivot_table_bill.applymap(float)

# Perform element-wise division between pivot_table_total_numeric and pivot_table_bill_numeric
result_df = pivot_table_total_numeric.div(pivot_table_bill_numeric)

# If you want to format the result as well, you can apply the formatting here
result_df = result_df.applymap("{:,.0f}".format)

# Display the resulting DataFrame
print(result_df)
# Out:
# Time Range         00:00-00:59 01:00-01:59 02:00-02:59 03:00-03:59  \
# StoreID Date
# VN0001  2023-01-01      57,954      52,312      60,667      39,000
#         2023-01-02      44,000     118,667      50,250     111,333
#         2023-01-03      62,000      89,200      25,800     106,000
#         2023-01-04      49,000     114,833      43,000         nan
#         2023-01-05     104,000      35,750     112,000      28,500
# ...                        ...         ...         ...         ...
# VN9996  2023-01-28         nan         nan         nan         nan
#         2023-01-29         nan         nan         nan         nan
#         2023-01-30         nan         nan         nan         nan
#         2023-01-31         nan         nan         nan         nan
#         2023-02-01         nan         nan         nan         nan
#
# Time Range         04:00-04:59 05:00-05:59 06:00-06:59 07:00-07:59  \
# StoreID Date
# VN0001  2023-01-01      33,000      42,000      41,222      75,167
#         2023-01-02      36,333      11,000      29,000      28,071
#         2023-01-03      33,000      79,667      29,944      27,936
#         2023-01-04      76,000      56,636      25,944      33,072
#         2023-01-05     139,000       6,000      40,923      27,977
# ...                        ...         ...         ...         ...
# VN9996  2023-01-28         nan         nan      27,333      30,308
#         2023-01-29         nan         nan         nan      40,500
#         2023-01-30         nan         nan      41,000      28,769
#         2023-01-31         nan         nan      72,000      23,400
#         2023-02-01         nan         nan         nan      20,125
#
# Time Range         08:00-08:59 09:00-09:59  ... 14:00-14:59 15:00-15:59  \
# StoreID Date                                ...
# VN0001  2023-01-01      27,000      38,412  ...      74,333      42,133
#         2023-01-02      37,933      61,111  ...      63,000      35,308
#         2023-01-03      35,326      29,704  ...      37,194      41,184
#         2023-01-04      33,515      33,918  ...      35,969      45,310
#         2023-01-05      41,277      35,348  ...      49,324      40,195
# ...                        ...         ...  ...         ...         ...
# VN9996  2023-01-28      60,368      46,600  ...      28,828      47,893
#         2023-01-29      35,341      35,658  ...      33,095      37,455
#         2023-01-30      39,667      37,920  ...      45,727      35,828
#         2023-01-31      30,000      31,000  ...      35,444      28,176
#         2023-02-01      34,933      34,526  ...      27,529      53,115
#
# Time Range         16:00-16:59 17:00-17:59 18:00-18:59 19:00-19:59  \
# StoreID Date
# VN0001  2023-01-01      44,176     102,632      33,083      54,500
#         2023-01-02      45,192      42,909      24,500      26,214
#         2023-01-03      40,293      47,333      34,657      48,464
#         2023-01-04      37,750      44,981      42,832      73,571
#         2023-01-05      33,558      67,636     154,364      62,000
# ...                        ...         ...         ...         ...
# VN9996  2023-01-28      42,946      45,160      43,353      39,206
#         2023-01-29      37,771      46,861      39,921      48,212
#         2023-01-30      44,344      37,952      36,587      44,400
#         2023-01-31      38,021      46,138      39,275      37,359
#         2023-02-01      49,031         nan         nan         nan
#
# Time Range         20:00-20:59 21:00-21:59 22:00-22:59 23:00-23:59
# StoreID Date
# VN0001  2023-01-01      82,789      67,640     101,174     140,364
#         2023-01-02      77,091      65,167      40,480      47,143
#         2023-01-03      48,560      84,800      80,700      36,300
#         2023-01-04      38,045      44,818      52,300      69,000
#         2023-01-05      47,840      87,722      67,667      61,727
# ...                        ...         ...         ...         ...
# VN9996  2023-01-28      47,821      48,976      51,455      39,615
#         2023-01-29      48,108      44,839      44,831      57,667
#         2023-01-30      39,586      48,254      46,672      34,167
#         2023-01-31      50,150      42,841      42,268      75,750
#         2023-02-01         nan         nan         nan         nan
#
# [40606 rows x 24 columns]

# %%
# Group data by 'Time Range', 'StoreID', and 'Barcode', and calculate the count of each barcode in each group
barcode_counts = df_grouped.groupby(['Time Range', 'StoreID', 'Barcode']).size().reset_index(name='Count')

# Sort the data by the count in descending order
sorted_barcode_counts = barcode_counts.sort_values(by='Count', ascending=False)

# Get the top 10 barcodes with the highest counts
top_10_barcodes = sorted_barcode_counts.head(10)

print(top_10_barcodes)
# Out:
#           Time Range StoreID        Barcode  Count
# 1742154  12:00-12:59  VN0134  2010101000005   2549
# 2120718  14:00-14:59  VN0134  2010101000005   2385
# 1093842  09:00-09:59  VN0060  8934588063053   2026
# 1742557  12:00-12:59  VN0134  8934588063053   1901
# 1675299  12:00-12:59  VN0060  8934588063053   1725
# 2121181  14:00-14:59  VN0134  8934588063053   1662
# 734314   07:00-07:59  VN0036  2010101000005   1460
# 1131234  09:00-09:59  VN0103  8934588063053   1453
# 2247033  15:00-15:59  VN0060  8934588063053   1425
# 971402   08:00-08:59  VN0134  8934588063053   1393

# %%
df_grouped
# Out:
#                    InvoiceID StoreID        Date      Time        Barcode  \
# 0         VN0001010101230001  VN0001  2023-01-01  00:40:59  8935049500544
# 1         VN0001010101230002  VN0001  2023-01-01  00:41:18  8938512632025
# 2         VN0001010101230003  VN0001  2023-01-01  00:41:55  8936011773416
# 3         VN0001010101230004  VN0001  2023-01-01  00:43:12  8801100128845
# 4         VN0001010101230005  VN0001  2023-01-01  00:44:22  8934588843051
# ...                      ...     ...         ...       ...            ...
# 15597313  VN9996023101230489  VN9996  2023-01-31  23:10:23  8936079121822
# 15597314  VN9996023101230490  VN9996  2023-01-31  23:11:47  8935112200005
# 15597315  VN9996023101230491  VN9996  2023-01-31  23:12:41  2010101000005
# 15597316  VN9996023101230492  VN9996  2023-01-31  23:12:56  8936031835118
# 15597317  VN9996023101230493  VN9996  2023-01-31  23:13:25  8802876204603
#
#           Total Include VAT   Time Range
# 0                    7000.0  00:00-00:59
# 1                   12000.0  00:00-00:59
# 2                  115000.0  00:00-00:59
# 3                  191000.0  00:00-00:59
# 4                   26000.0  00:00-00:59
# ...                     ...          ...
# 15597313           175000.0  23:00-23:59
# 15597314            13000.0  23:00-23:59
# 15597315             3000.0  23:00-23:59
# 15597316            47000.0  23:00-23:59
# 15597317           358000.0  23:00-23:59
#
# [15597318 rows x 7 columns]

# %%
# Backup df_grouped to df_grouped_bk
df_grouped_bk = df_grouped

df_grouped_bk
# Out:
#                    InvoiceID StoreID        Date      Time        Barcode  \
# 0         VN0001010101230001  VN0001  2023-01-01  00:40:59  8935049500544
# 1         VN0001010101230002  VN0001  2023-01-01  00:41:18  8938512632025
# 2         VN0001010101230003  VN0001  2023-01-01  00:41:55  8936011773416
# 3         VN0001010101230004  VN0001  2023-01-01  00:43:12  8801100128845
# 4         VN0001010101230005  VN0001  2023-01-01  00:44:22  8934588843051
# ...                      ...     ...         ...       ...            ...
# 15597313  VN9996023101230489  VN9996  2023-01-31  23:10:23  8936079121822
# 15597314  VN9996023101230490  VN9996  2023-01-31  23:11:47  8935112200005
# 15597315  VN9996023101230491  VN9996  2023-01-31  23:12:41  2010101000005
# 15597316  VN9996023101230492  VN9996  2023-01-31  23:12:56  8936031835118
# 15597317  VN9996023101230493  VN9996  2023-01-31  23:13:25  8802876204603
#
#           Total Include VAT   Time Range
# 0                    7000.0  00:00-00:59
# 1                   12000.0  00:00-00:59
# 2                  115000.0  00:00-00:59
# 3                  191000.0  00:00-00:59
# 4                   26000.0  00:00-00:59
# ...                     ...          ...
# 15597313           175000.0  23:00-23:59
# 15597314            13000.0  23:00-23:59
# 15597315             3000.0  23:00-23:59
# 15597316            47000.0  23:00-23:59
# 15597317           358000.0  23:00-23:59
#
# [15597318 rows x 7 columns]

# %%
from datetime import datetime
import pandas as pd

# Use backup DataFrame
df_grouped = df_grouped_bk
# Create the DataFrame
df = df_grouped

# Function to convert time string to a proper time format
def convert_to_time(time_str):
    try:
        return datetime.strptime(time_str, '%H:%M:%S').strftime('%H:%M')
    except ValueError:
        return None

# Function to get Time Range for each Time value
def get_time_range(time_str):
    time_str = convert_to_time(time_str)
    if time_str is None:
        return None
    hour = int(time_str[:2])
    time_range_start = f"{hour:02}:00"
    time_range_end = f"{hour:02}:59"
    return f"{time_range_start}-{time_range_end}"

# Add new column Time Range
df['Time Range'] = df['Time'].apply(get_time_range)

# Now, let's find the top 10 barcodes for each time range
# Group the data by 'StoreID', 'Date', 'Time Range', and 'Barcode', and count the occurrences
df_grouped = df.groupby(['StoreID', 'Date', 'Time Range', 'Barcode']).size().reset_index(name='Count')

# Sort the data by 'StoreID', 'Date', 'Time Range', and the count in descending order
df_grouped = df_grouped.sort_values(by=['StoreID', 'Date', 'Time Range', 'Count'], ascending=[True, True, True, False])

# Add the 'Rank' column based on the count
df_grouped['Rank'] = df_grouped.groupby(['StoreID', 'Date', 'Time Range'])['Count'].rank(ascending=False, method='first')

# Filter the top 10 barcodes for each time range
top_10_barcodes_all_time_ranges = df_grouped[df_grouped['Rank'] <= 10]

# Display the result
top_10_barcodes_all_time_ranges
# Out:
#          StoreID        Date   Time Range        Barcode  Count  Rank
# 47        VN0001  2023-01-01  00:00-00:59  8938512632025      4   1.0
# 0         VN0001  2023-01-01  00:00-00:59  2010101000005      3   2.0
# 20        VN0001  2023-01-01  00:00-00:59  8934588843051      3   3.0
# 31        VN0001  2023-01-01  00:00-00:59  8935049500544      3   4.0
# 34        VN0001  2023-01-01  00:00-00:59  8935049501503      3   5.0
# ...          ...         ...          ...            ...    ...   ...
# 13680552  VN9996  2023-02-01  16:00-16:59  2010403000185      1   6.0
# 13680553  VN9996  2023-02-01  16:00-16:59  2010805000028      1   7.0
# 13680554  VN9996  2023-02-01  16:00-16:59  8850157400107      1   8.0
# 13680555  VN9996  2023-02-01  16:00-16:59  8858223013039      1   9.0
# 13680556  VN9996  2023-02-01  16:00-16:59  8934564600357      1  10.0
#
# [7451029 rows x 6 columns]

# %%
df_grouped
# Out:
#          StoreID        Date   Time Range        Barcode  Count  Rank
# 47        VN0001  2023-01-01  00:00-00:59  8938512632025      4   1.0
# 0         VN0001  2023-01-01  00:00-00:59  2010101000005      3   2.0
# 20        VN0001  2023-01-01  00:00-00:59  8934588843051      3   3.0
# 31        VN0001  2023-01-01  00:00-00:59  8935049500544      3   4.0
# 34        VN0001  2023-01-01  00:00-00:59  8935049501503      3   5.0
# ...          ...         ...          ...            ...    ...   ...
# 13680564  VN9996  2023-02-01  16:00-16:59  8935049501503      1  16.0
# 13680567  VN9996  2023-02-01  16:00-16:59  8936079140014      1  17.0
# 13680568  VN9996  2023-02-01  16:00-16:59  8936079140076      1  18.0
# 13680569  VN9996  2023-02-01  16:00-16:59  8936127791014      1  19.0
# 13680570  VN9996  2023-02-01  16:00-16:59  8936149340047      1  20.0
#
# [13680571 rows x 6 columns]

# %%
test = df_grouped[(df_grouped['StoreID'] == 'VN0043') & (df_grouped['Date'] == '2023-01-06') & (df_grouped['Time Range'] == '18:00-18:59')]
test
# Out:
#         StoreID        Date   Time Range        Barcode  Count  Rank
# 2379475  VN0043  2023-01-06  18:00-18:59  8934588063053      3   1.0
# 2379471  VN0043  2023-01-06  18:00-18:59  2010902000228      2   2.0
# 2379489  VN0043  2023-01-06  18:00-18:59  8936185350130      2   3.0
# 2379465  VN0043  2023-01-06  18:00-18:59    89686043686      1   4.0
# 2379466  VN0043  2023-01-06  18:00-18:59   770795005619      1   5.0
# 2379467  VN0043  2023-01-06  18:00-18:59  2010805000202      1   6.0
# 2379468  VN0043  2023-01-06  18:00-18:59  2010805000226      1   7.0
# 2379469  VN0043  2023-01-06  18:00-18:59  2010805000356      1   8.0
# 2379470  VN0043  2023-01-06  18:00-18:59  2010805000363      1   9.0
# 2379472  VN0043  2023-01-06  18:00-18:59  2260101000134      1  10.0
# 2379473  VN0043  2023-01-06  18:00-18:59  2270102000361      1  11.0
# 2379474  VN0043  2023-01-06  18:00-18:59  8888589390130      1  12.0
# 2379476  VN0043  2023-01-06  18:00-18:59  8934614030424      1  13.0
# 2379477  VN0043  2023-01-06  18:00-18:59  8934680033107      1  14.0
# 2379478  VN0043  2023-01-06  18:00-18:59  8935001701699      1  15.0
# 2379479  VN0043  2023-01-06  18:00-18:59  8935015402254      1  16.0
# 2379480  VN0043  2023-01-06  18:00-18:59  8935049500711      1  17.0
# 2379481  VN0043  2023-01-06  18:00-18:59  8935049501374      1  18.0
# 2379482  VN0043  2023-01-06  18:00-18:59  8935112200005      1  19.0
# 2379483  VN0043  2023-01-06  18:00-18:59  8935117702115      1  20.0
# 2379484  VN0043  2023-01-06  18:00-18:59  8936011774024      1  21.0
# 2379485  VN0043  2023-01-06  18:00-18:59  8936011774031      1  22.0
# 2379486  VN0043  2023-01-06  18:00-18:59  8936036027877      1  23.0
# 2379487  VN0043  2023-01-06  18:00-18:59  8936049051722      1  24.0
# 2379488  VN0043  2023-01-06  18:00-18:59  8936094291005      1  25.0
# 2379490  VN0043  2023-01-06  18:00-18:59  8938502525344      1  26.0
# 2379491  VN0043  2023-01-06  18:00-18:59  8938511021127      1  27.0
# 2379492  VN0043  2023-01-06  18:00-18:59  8938511702446      1  28.0
# 2379493  VN0043  2023-01-06  18:00-18:59  8938512632025      1  29.0
# 2379494  VN0043  2023-01-06  18:00-18:59  8938539302017      1  30.0
# 2379495  VN0043  2023-01-06  18:00-18:59  8997035601321      1  31.0

# %%
# query to get top 10 barcodes for time range 23:00-23:59 and store VN0001
df_query = top_10_barcodes_all_time_ranges[(top_10_barcodes_all_time_ranges['Time Range'] == '18:00-18:59') & (top_10_barcodes_all_time_ranges['StoreID'] == 'VN0043') & (top_10_barcodes_all_time_ranges['Date'] == '2023-01-06')]

# %%
df_query
# Out:
#         StoreID        Date   Time Range        Barcode  Count  Rank
# 2379475  VN0043  2023-01-06  18:00-18:59  8934588063053      3   1.0
# 2379471  VN0043  2023-01-06  18:00-18:59  2010902000228      2   2.0
# 2379489  VN0043  2023-01-06  18:00-18:59  8936185350130      2   3.0
# 2379465  VN0043  2023-01-06  18:00-18:59    89686043686      1   4.0
# 2379466  VN0043  2023-01-06  18:00-18:59   770795005619      1   5.0
# 2379467  VN0043  2023-01-06  18:00-18:59  2010805000202      1   6.0
# 2379468  VN0043  2023-01-06  18:00-18:59  2010805000226      1   7.0
# 2379469  VN0043  2023-01-06  18:00-18:59  2010805000356      1   8.0
# 2379470  VN0043  2023-01-06  18:00-18:59  2010805000363      1   9.0
# 2379472  VN0043  2023-01-06  18:00-18:59  2260101000134      1  10.0

# %%
df_grouped_bk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15597318 entries, 0 to 15597317
# Data columns (total 7 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   InvoiceID          object
#  1   StoreID            object
#  2   Date               object
#  3   Time               object
#  4   Barcode            int64
#  5   Total Include VAT  float64
#  6   Time Range         object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 833.0+ MB

# %%
# Convert 'Barcode' column to a consistent data type in both dataframes
df_grouped_bk['Barcode'] = df_grouped_bk['Barcode'].astype(str)
df_cate['Barcode'] = df_cate['Barcode'].astype(str)

# Perform the merge
test_df = df_grouped_bk.merge(df_cate, how='left', on='Barcode')

# Continue with your filtering
test_df_query = test_df[(test_df['StoreID'] == 'VN0043') & 
                        (test_df['Date'] == '2023-01-06') & 
                        (test_df['Time Range'] == '18:00-18:59') ]

test_df_query
# Out:
#                   InvoiceID StoreID        Date      Time        Barcode  \
# 2860211  VN0043010601230285  VN0043  2023-01-06  18:02:40  8935049500711
# 2860212  VN0043010601230286  VN0043  2023-01-06  18:08:42  8938511021127
# 2860213  VN0043010601230287  VN0043  2023-01-06  18:09:12  2010902000228
# 2860214  VN0043010601230287  VN0043  2023-01-06  18:09:12  2010902000228
# 2860215  VN0043010601230288  VN0043  2023-01-06  18:14:37  8934588063053
# 2860216  VN0043010601230289  VN0043  2023-01-06  18:29:07  8935049501374
# 2860217  VN0043010601230290  VN0043  2023-01-06  18:44:14  8934588063053
# 2860218  VN0043010601230291  VN0043  2023-01-06  18:53:01  8936094291005
# 2860219  VN0043010601230292  VN0043  2023-01-06  18:56:01  8935001701699
# 2860220  VN0043010601230293  VN0043  2023-01-06  18:56:57  8934680033107
# 2860221  VN0043010601230294  VN0043  2023-01-06  18:58:23  2010805000226
# 2860222  VN0043010601230295  VN0043  2023-01-06  18:59:13  8936185350130
# 2924200  VN0043020601230124  VN0043  2023-01-06  18:00:25   770795005619
# 2924201  VN0043020601230125  VN0043  2023-01-06  18:01:22  8936011774024
# 2924202  VN0043020601230126  VN0043  2023-01-06  18:04:45  8938502525344
# 2924203  VN0043020601230127  VN0043  2023-01-06  18:17:19  8935015402254
# 2924204  VN0043020601230128  VN0043  2023-01-06  18:19:34  8934614030424
# 2924205  VN0043020601230129  VN0043  2023-01-06  18:20:58  2010805000202
# 2924206  VN0043020601230130  VN0043  2023-01-06  18:23:01  8935112200005
# 2924207  VN0043020601230131  VN0043  2023-01-06  18:23:40  2010902000228
# 2924208  VN0043020601230131  VN0043  2023-01-06  18:23:40  2010902000228
# 2924209  VN0043020601230132  VN0043  2023-01-06  18:23:53  8997035601321
# 2924210  VN0043020601230133  VN0043  2023-01-06  18:24:55  2010805000363
# 2924211  VN0043020601230134  VN0043  2023-01-06  18:25:40  2270102000361
# 2924212  VN0043020601230135  VN0043  2023-01-06  18:27:34  2010805000356
# 2924213  VN0043020601230136  VN0043  2023-01-06  18:29:23  8936049051722
# 2924214  VN0043020601230137  VN0043  2023-01-06  18:31:28  8936036027877
# 2924215  VN0043020601230138  VN0043  2023-01-06  18:33:37  8938512632025
# 2924216  VN0043020601230139  VN0043  2023-01-06  18:34:09  8938511702446
# 2924217  VN0043020601230140  VN0043  2023-01-06  18:36:20  8938539302017
# 2924218  VN0043020601230141  VN0043  2023-01-06  18:39:54  2260101000134
# 2924219  VN0043020601230142  VN0043  2023-01-06  18:41:21  8935117702115
# 2924220  VN0043020601230143  VN0043  2023-01-06  18:41:55  8936011774031
# 2924221  VN0043020601230144  VN0043  2023-01-06  18:42:20  8888589390130
# 2924222  VN0043020601230145  VN0043  2023-01-06  18:47:12    89686043686
# 2924223  VN0043020601230146  VN0043  2023-01-06  18:47:48  8936185350130
# 2924224  VN0043020601230147  VN0043  2023-01-06  18:50:15  8934588063053
#
#          Total Include VAT   Time Range    Division Name  \
# 2860211            89000.0  18:00-18:59         Beverage
# 2860212             4000.0  18:00-18:59      LivingGoods
# 2860213            28000.0  18:00-18:59       FF Offsite
# 2860214            28000.0  18:00-18:59       FF Offsite
# 2860215            16000.0  18:00-18:59         Beverage
# 2860216            32000.0  18:00-18:59         Beverage
# 2860217            99000.0  18:00-18:59         Beverage
# 2860218            47000.0  18:00-18:59             Beer
# 2860219            17000.0  18:00-18:59            Candy
# 2860220           108000.0  18:00-18:59  Biscuit&Cookies
# 2860221            34000.0  18:00-18:59        FF Onsite
# 2860222            60000.0  18:00-18:59         Beverage
# 2924200            36000.0  18:00-18:59           Snacks
# 2924201            93000.0  18:00-18:59        Ice Cream
# 2924202            47000.0  18:00-18:59        FF Onsite
# 2924203            26000.0  18:00-18:59         Beverage
# 2924204            17000.0  18:00-18:59             Milk
# 2924205            21000.0  18:00-18:59        FF Onsite
# 2924206            49000.0  18:00-18:59         Beverage
# 2924207            18000.0  18:00-18:59       FF Offsite
# 2924208            18000.0  18:00-18:59       FF Offsite
# 2924209            28000.0  18:00-18:59         Beverage
# 2924210            28000.0  18:00-18:59        FF Onsite
# 2924211            56000.0  18:00-18:59       FF Offsite
# 2924212            29000.0  18:00-18:59        FF Onsite
# 2924213            17000.0  18:00-18:59          Grocery
# 2924214            15000.0  18:00-18:59           Snacks
# 2924215            12000.0  18:00-18:59         Beverage
# 2924216            87000.0  18:00-18:59             Beer
# 2924217           140000.0  18:00-18:59    Fresh Grocery
# 2924218            27000.0  18:00-18:59        FF Onsite
# 2924219             9000.0  18:00-18:59          Dessert
# 2924220            12000.0  18:00-18:59        Ice Cream
# 2924221            16000.0  18:00-18:59         Beverage
# 2924222             7000.0  18:00-18:59              NaN
# 2924223            33000.0  18:00-18:59         Beverage
# 2924224            13000.0  18:00-18:59         Beverage
#
#                         Category Name      SubCategory Name  \
# 2860211                           Tea             Sugar Tea
# 2860212   Paper/Plastic/Foil Products                Tissue
# 2860213                 Rice  Offsite               Onigiri
# 2860214                 Rice  Offsite               Onigiri
# 2860215                 Bottled Water        Purified water
# 2860216       Carbonated Drinks - CSD     No/Less Sugar CSD
# 2860217                 Bottled Water        Purified water
# 2860218                   Import Beer       Import Beer Can
# 2860219                Candy Category            Hard Candy
# 2860220                      Biscuits              Wafflers
# 2860221                 Other Cuisine     Other Cuisine Sub
# 2860222               Others Beverage         Others Drinks
# 2924200             Snacks for Drinks            Nuts/Seeds
# 2924201  Packaged Ice Cream/Novelties                Corner
# 2924202                   Steamed Bun         Savoury  Buns
# 2924203       Carbonated Drinks - CSD             Sugar CSD
# 2924204                    Whole Milk              Soy milk
# 2924205                 Other Cuisine     Other Cuisine Sub
# 2924206                 Energy Drinks     Energy Drinks Sub
# 2924207                 Rice  Offsite               Onigiri
# 2924208                 Rice  Offsite               Onigiri
# 2924209                 Sports Drinks     Sports Drinks Sub
# 2924210                 Other Cuisine     Other Cuisine Sub
# 2924211                 Rice  Offsite               Onigiri
# 2924212                 Other Cuisine     Other Cuisine Sub
# 2924213               Instant Noodles  Instant Noodles Pack
# 2924214                  Potato Chips         Potato Snacks
# 2924215                 Bottled Water        Purified water
# 2924216                 Domestic Beer   Domestic Craft Beer
# 2924217                     Fruit Cat             Fruit Sub
# 2924218                Fried Food Cat        Fried Food Sub
# 2924219                   Dessert Cat           Dessert Sub
# 2924220  Packaged Ice Cream/Novelties                Corner
# 2924221                           Tea             Sugar Tea
# 2924222                           NaN                   NaN
# 2924223               Others Beverage         Others Drinks
# 2924224                 Bottled Water        Purified water
#
#                                                  Item Name
# 2860211     FUZETEA+ Trà chanh dây hạt chia 450ml x 1 Chai
# 2860212                    #Khăn ướt có cồn Max Cool x cái
# 2860213                      Cơm nắm bò gochujang siêu cay
# 2860214                     #Cơm nắm bò gochujang siêu cay
# 2860215             AQUAFINA Nước tinh khiết 500ml x1 Chai
# 2860216                    COCA COLA ít đường 600ml x Chai
# 2860217             AQUAFINA Nước tinh khiết 500ml x1 Chai
# 2860218                   Budweiser Bia Sleek 330ml x 1lon
# 2860219  ALPENLIEBE Kẹo Truyền Thống Vị Caramel 115.5g ...
# 2860220           Cosy Bánh Quế Vị Kem Lá Dứa 126g x 1 Gói
# 2860221                           Mì trộn xúc xích  x 1 to
# 2860222                     KOMBUCHA  vị Cam Đào 240mlxLon
# 2924200                     DanD Hạt Điều Muối 50g x 1 gói
# 2924201           MERINO Kem Ốc quế Supper Teen 60g x1 Cây
# 2924202                  Bánh bao 2 trứng cút 150g x 1 Cái
# 2924203                  CHƯƠNG DƯƠNG Sá xị 390ml x 1 Chai
# 2924204               FAMI Sữa đậu nành canxi 200ml x1 Hộp
# 2924205                                    Mì trộn  x 1 to
# 2924206                 REDBULL Nước tăng lực 250ml x1 Lon
# 2924207                      Cơm nắm bò gochujang siêu cay
# 2924208                     #Cơm nắm bò gochujang siêu cay
# 2924209                          POCARI Sweat 900ml x chai
# 2924210                                Hotdog 25 Signature
# 2924211                            Cơm nắm kim chi phô mai
# 2924212                                          Hotdog 25
# 2924213         OTTOGI Mì Jin lẩu thái chua cay 115g x gói
# 2924214               SWING KTC vị phô mai 2 lớp 56g x gói
# 2924215              SATORI Nước tinh khiết 500ml x 1 Chai
# 2924216            #Bia Dream Alone Pale Ale 330ml x 1 lon
# 2924217                       #AF Dừa tươi tiện lợi x trái
# 2924218                  Viên mochi phô mai chiên x 1 phần
# 2924219                     ÁNH HỒNG Thạch Dừa 190g x 1 ly
# 2924220    MERINO Kem ốc quế Supper Teen socola 60g x1 Cây
# 2924221                           JJ trà chanh 300ml x lon
# 2924222                                                NaN
# 2924223                     KOMBUCHA  vị Cam Đào 240mlxLon
# 2924224             AQUAFINA Nước tinh khiết 500ml x1 Chai

# %%
top_10_barcodes_all_time_ranges['Barcode'] = top_10_barcodes_all_time_ranges['Barcode'].astype(str)

top_10_barcodes_all_time_ranges = top_10_barcodes_all_time_ranges.merge(df_cate, on='Barcode', how='left')
# Display head()

top_10_barcodes_all_time_ranges
# Out:
# C:\Users\Trieu\AppData\Local\Temp\ipykernel_13928\604459695.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_barcodes_all_time_ranges['Barcode'] = top_10_barcodes_all_time_ranges['Barcode'].astype(str)
#         StoreID        Date   Time Range        Barcode  Count  Rank  \
# 0        VN0001  2023-01-01  00:00-00:59  8938512632025      4   1.0
# 1        VN0001  2023-01-01  00:00-00:59  2010101000005      3   2.0
# 2        VN0001  2023-01-01  00:00-00:59  8934588843051      3   3.0
# 3        VN0001  2023-01-01  00:00-00:59  8935049500544      3   4.0
# 4        VN0001  2023-01-01  00:00-00:59  8935049501503      3   5.0
# ...         ...         ...          ...            ...    ...   ...
# 7749141  VN9996  2023-02-01  16:00-16:59  2010403000185      1   6.0
# 7749142  VN9996  2023-02-01  16:00-16:59  2010805000028      1   7.0
# 7749143  VN9996  2023-02-01  16:00-16:59  8850157400107      1   8.0
# 7749144  VN9996  2023-02-01  16:00-16:59  8858223013039      1   9.0
# 7749145  VN9996  2023-02-01  16:00-16:59  8934564600357      1  10.0
#
#         Division Name            Category Name    SubCategory Name  \
# 0            Beverage            Bottled Water      Purified water
# 1         FF Beverage           Cold Beverages          Cup Of Ice
# 2            Beverage            Sports Drinks   Sports Drinks Sub
# 3            Beverage            Bottled Water       Mineral water
# 4            Beverage  Carbonated Drinks - CSD           Sugar CSD
# ...               ...                      ...                 ...
# 7749141   FF Beverage                FF Coffee        Local Coffee
# 7749142     FF Onsite            Other Cuisine  Korean cuisine Sub
# 7749143        Snacks        Snacks for Drinks         Meat snacks
# 7749144        Snacks         Non-potato Chips  Alternative Snacks
# 7749145      Beverage                      Tea           Sugar Tea
#
#                                             Item Name
# 0               SATORI Nước tinh khiết 500ml x 1 Chai
# 1                                     Ly đá vừa x 1ly
# 2                             7UP Revive 500mlx1 Chai
# 3                    DASANI Nước khoáng 510ml x1 Chai
# 4        COCA Nước giải khát có ga sleek 320ml x1 Lon
# ...                                               ...
# 7749141              #Dr_Coffee.Café sữa đá 12oz x ly
# 7749142                Tteokbokki truyền thống x 1 tô
# 7749143       BENTO Mực nướng vị cay ngọt 18g x 1 gói
# 7749144           Mix Snack Que Rong Biển 60g x 1 Gói
# 7749145   Nước C2 trà xanh Hương Chanh 455ml x 1 chai
#
# [7749146 rows x 10 columns]
