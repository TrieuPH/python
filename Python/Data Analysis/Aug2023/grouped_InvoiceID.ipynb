# %%
#import libraries
import pandas as pd
import os
import configparser

# Read the value from the config.ini file
config = configparser.ConfigParser()
config.read('config.ini')
output_file_dir = config.get('path', 'output_file_dir')
output_file_name_net_sales = config.get('path', 'output_file_name_net_sales')
cateFileDir = config.get('path', 'cateFileDir')
# Read the category file
try:
    df_cate = pd.read_excel(cateFileDir)
except FileNotFoundError as e:
    # Hard code the category file path
    df_cate = pd.read_excel(r'...')# Hard code the category file path

# Read the net sales file
net_sales_data = os.path.join(output_file_dir, output_file_name_net_sales) + '.csv'

# Read the merged file csv
# input_file should be the path of the file
try:
    input_file = net_sales_data
    df = pd.read_csv(input_file)
except FileNotFoundError as e:
    # Hard code the path of the file
    input_file = r"..."
    df = pd.read_csv(input_file)
df.dropna(inplace=True)

# %%
print(df.head(5))
print(df_cate.head(5))
# Out:
#          Date      Time           InvoiceID        Barcode  Total Include VAT
# 0  2023-01-01  00:40:59  VN0001010101230001  8935049500544             7000.0
# 1  2023-01-01  00:41:18  VN0001010101230002  8938512632025            12000.0
# 2  2023-01-01  00:41:55  VN0001010101230003  8936011773416            25000.0
# 3  2023-01-01  00:41:55  VN0001010101230003  8936079121761            13000.0
# 4  2023-01-01  00:41:55  VN0001010101230003  8850453017528            13000.0
#          Barcode Division Name   Category Name          SubCategory Name
# 0  9956991810612   LivingGoods    Living goods  Other Non-edible Grocery  \
# 1       96183519         Candy  Candy Category                Hard Candy
# 2       96118528         Candy  Candy Category                Hard Candy
# 3       96118511         Candy  Candy Category                Hard Candy
# 4       96118504         Candy  Candy Category                Hard Candy
#
#                                            Item Name
# 0                          #Alladdin bật lửa x 1 cái
# 1  FISHERMANS Kẹo cay con tàu vị táo quế bạc hà 2...
# 2  FISHERMANS Kẹo cay con tàu vị spearmint 25g x1...
# 3     FISHERMANS Kẹo cay Cherry & Method 25g x 1 gói
# 4              FISHERMANS Kẹo quýt bạc hà 25g x1 gói

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                 Date      Time           InvoiceID        Barcode
# 0         2023-01-01  00:40:59  VN0001010101230001  8935049500544  \
# 1         2023-01-01  00:41:18  VN0001010101230002  8938512632025
# 2         2023-01-01  00:41:55  VN0001010101230003  8936011773416
# 3         2023-01-01  00:41:55  VN0001010101230003  8936079121761
# 4         2023-01-01  00:41:55  VN0001010101230003  8850453017528
# ...              ...       ...                 ...            ...
# 68978410  2023-07-05  18:58:59  VN0061010507230308  8935250402019
# 68978411  2023-07-05  13:02:59  VN0061010507230185  8934803071085
# 68978412  2023-07-05  09:15:59  VN0061010507230092  8935090910873
# 68978413  2023-07-05  09:15:59  VN0061010507230092  8935005800015
# 68978414  2023-07-05  09:15:59  VN0061010507230092  2120201000017
#
#           Total Include VAT
# 0                    7000.0
# 1                   12000.0
# 2                   25000.0
# 3                   13000.0
# 4                   13000.0
# ...                     ...
# 68978410            48000.0
# 68978411            13000.0
# 68978412            36000.0
# 68978413            12000.0
# 68978414             9000.0
#
# [34840920 rows x 5 columns]

# %%
# Convert the data type of the column 'Barcode' to string
df_cate['Barcode'] = df_cate['Barcode'].astype(str)
df['Barcode'] = df['Barcode'].astype(str)

# Merge the two dataframes
df_merged = pd.merge(df, df_cate, on='Barcode', how='left')

# %%
df_merged
# Out:
#                 Date      Time           InvoiceID        Barcode
# 0         2023-01-01  00:40:59  VN0001010101230001  8935049500544  \
# 1         2023-01-01  00:41:18  VN0001010101230002  8938512632025
# 2         2023-01-01  00:41:55  VN0001010101230003  8936011773416
# 3         2023-01-01  00:41:55  VN0001010101230003  8936079121761
# 4         2023-01-01  00:41:55  VN0001010101230003  8850453017528
# ...              ...       ...                 ...            ...
# 35898463  2023-07-05  18:58:59  VN0061010507230308  8935250402019
# 35898464  2023-07-05  13:02:59  VN0061010507230185  8934803071085
# 35898465  2023-07-05  09:15:59  VN0061010507230092  8935090910873
# 35898466  2023-07-05  09:15:59  VN0061010507230092  8935005800015
# 35898467  2023-07-05  09:15:59  VN0061010507230092  2120201000017
#
#           Total Include VAT  Division Name                 Category Name
# 0                    7000.0       Beverage                 Bottled Water  \
# 1                   12000.0       Beverage                 Bottled Water
# 2                   25000.0      Ice Cream  Packaged Ice Cream/Novelties
# 3                   13000.0         Snacks                  Potato Chips
# 4                   13000.0      Ice Cream  Packaged Ice Cream/Novelties
# ...                     ...            ...                           ...
# 35898463            48000.0    LivingGoods   Paper/Plastic/Foil Products
# 35898464            13000.0         Snacks              Non-potato Chips
# 35898465            36000.0         Snacks             Snacks for Drinks
# 35898466            12000.0       Beverage                 Bottled Water
# 35898467             9000.0  Fresh Grocery                     Fruit Cat
#
#          SubCategory Name                                          Item Name
# 0           Mineral water                   DASANI Nước khoáng 510ml x1 Chai
# 1          Purified water              SATORI Nước tinh khiết 500ml x 1 Chai
# 2         Other Ice Cream  #Celano Kem Bánh Cá Trân Châu Dừa Tắc 70g * 1 cây
# 3           Potato Snacks     Lay's Wavy Vị Thăn Bò Nướng Texas 58gr x 1 gói
# 4                   Stick                      MILO Kem que Magma 55g x1 Cây
# ...                   ...                                                ...
# 35898463           Tissue                        EMOS Khan An 100pcs x 1 Gói
# 35898464     Salty Snacks                 OISHI Snack Tôm cay nồng 70g x gói
# 35898465       Nuts/Seeds              DanD Hạnh Nhân Không Muối 50g x 1 gói
# 35898466    Mineral water                   LAVIE Nuoc Khoang 750ml x 1 Chai
# 35898467        Fruit Sub                 U&I Chuối cavendish DOLE - trái lẻ
#
# [35898468 rows x 9 columns]

# %%
df_filter = df_merged[['InvoiceID', 'Barcode', 'Total Include VAT', 'Division Name']]

df_filter
# Out:
#                    InvoiceID        Barcode  Total Include VAT  Division Name
# 0         VN0001010101230001  8935049500544             7000.0       Beverage
# 1         VN0001010101230002  8938512632025            12000.0       Beverage
# 2         VN0001010101230003  8936011773416            25000.0      Ice Cream
# 3         VN0001010101230003  8936079121761            13000.0         Snacks
# 4         VN0001010101230003  8850453017528            13000.0      Ice Cream
# ...                      ...            ...                ...            ...
# 35898463  VN0061010507230308  8935250402019            48000.0    LivingGoods
# 35898464  VN0061010507230185  8934803071085            13000.0         Snacks
# 35898465  VN0061010507230092  8935090910873            36000.0         Snacks
# 35898466  VN0061010507230092  8935005800015            12000.0       Beverage
# 35898467  VN0061010507230092  2120201000017             9000.0  Fresh Grocery
#
# [35898468 rows x 4 columns]

# %%
group_by_invoice = df_filter.groupby('InvoiceID').agg({'Barcode': lambda x: ', '.join(x.astype(str)), 
                                      'Total Include VAT': 'sum', 
                                      'Division Name': lambda x: ', '.join(x.astype(str))}).reset_index()
group_by_invoice
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\apply.py:420, in Apply.agg_dict_like(self)
#     418     else:
#     419         # key used for column selection and output
# --> 420         results = {
#     421             key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     422         }
#     424 # set the final keys
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\apply.py:421, in <dictcomp>(.0)
#     418     else:
#     419         # key used for column selection and output
#     420         results = {
# --> 421             key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     422         }
#     424 # set the final keys
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\groupby\generic.py:252, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     250     return getattr(self, cyfunc)()
# --> 252 if self.ngroups == 0:
#     253     # e.g. test_evaluate_with_empty_groups without any groups to
#     254     #  iterate over, we have no output on which to do dtype
#     255     #  inference. We default to using the existing dtype.
#     256     #  xref GH#51445
#     257     obj = self._obj_with_exclusions
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\groupby\groupby.py:653, in BaseGroupBy.ngroups(self)
#     650 @final
#     651 @property
#     652 def ngroups(self) -> int:
# --> 653     return self.grouper.ngroups
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\groupby\ops.py:902, in BaseGrouper.ngroups(self)
#     899 @final
#     900 @cache_readonly
#     901 def ngroups(self) -> int:
# --> 902     return len(self.result_index)
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\groupby\ops.py:913, in BaseGrouper.result_index(self)
#     912 if len(self.groupings) == 1:
# --> 913     return self.groupings[0].result_index.rename(self.names[0])
#     915 codes = self.reconstructed_codes
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\groupby\grouper.py:698, in Grouping.result_index(self)
#     697     return group_idx.set_categories(cats)  # type: ignore[attr-defined]
# --> 698 return self.group_index
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\groupby\grouper.py:702, in Grouping.group_index(self)
#     700 @cache_readonly
#     701 def group_index(self) -> Index:
# --> 702     codes, uniques = self._codes_and_uniques
#     703     if not self._dropna and self._passed_categorical:
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\groupby\grouper.py:780, in Grouping._codes_and_uniques(self)
#     776 else:
#     777     # GH35667, replace dropna=False with use_na_sentinel=False
#     778     # error: Incompatible types in assignment (expression has type "Union[
#     779     # ndarray[Any, Any], Index]", variable has type "Categorical")
# --> 780     codes, uniques = algorithms.factorize(  # type: ignore[assignment]
#     781         self.grouping_vector, sort=self._sort, use_na_sentinel=self._dropna
#     782     )
#     783 return codes, uniques
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\algorithms.py:779, in factorize(values, sort, use_na_sentinel, size_hint)
#     777             values = np.where(null_mask, na_value, values)
# --> 779     codes, uniques = factorize_array(
#     780         values,
#     781         use_na_sentinel=use_na_sentinel,
#     782         size_hint=size_hint,
#     783     )
#     785 if sort and len(uniques) > 0:
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\algorithms.py:580, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     579 table = hash_klass(size_hint or len(values))
# --> 580 uniques, codes = table.factorize(
#     581     values,
#     582     na_sentinel=-1,
#     583     na_value=na_value,
#     584     mask=mask,
#     585     ignore_na=use_na_sentinel,
#     586 )
#     588 # re-cast e.g. i8->dt64/td64, uint8->bool
#
# File pandas\_libs\hashtable_class_helper.pxi:7023, in pandas._libs.hashtable.StringHashTable.factorize()
#
# File pandas\_libs\hashtable_class_helper.pxi:6912, in pandas._libs.hashtable.StringHashTable._unique()
#
# MemoryError: Unable to allocate 274. MiB for an array with shape (35898468,) and data type int64
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 group_by_invoice = df_filter.groupby('InvoiceID').agg({'Barcode': lambda x: ', '.join(x.astype(str)),
#       2                                       'Total Include VAT': 'sum',
#       3                                       'Division Name': lambda x: ', '.join(x.astype(str))}).reset_index()
#       4 group_by_invoice.to_csv('group_by_invoice.csv', index=False, encoding='utf-8-sig')
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\groupby\generic.py:1269, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1266 func = maybe_mangle_lambdas(func)
#    1268 op = GroupByApply(self, func, args, kwargs)
# -> 1269 result = op.agg()
#    1270 if not is_dict_like(func) and result is not None:
#    1271     return result
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\apply.py:163, in Apply.agg(self)
#     160     return self.apply_str()
#     162 if is_dict_like(arg):
# --> 163     return self.agg_dict_like()
#     164 elif is_list_like(arg):
#     165     # we require a list, but not a 'str'
#     166     return self.agg_list_like()
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\apply.py:413, in Apply.agg_dict_like(self)
#     411 else:
#     412     context_manager = nullcontext()
# --> 413 with context_manager:
#     414     if selected_obj.ndim == 1:
#     415         # key only used for output
#     416         colg = obj._gotitem(selection, ndim=1)
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\contextlib.py:141, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     138     except StopIteration:
#     139         raise RuntimeError("generator didn't yield") from None
# --> 141 def __exit__(self, typ, value, traceback):
#     142     if typ is None:
#     143         try:
#
# KeyboardInterrupt:

# %%
# group_by_invoice.to_csv('group_by_invoice.csv', index=False, encoding='utf-8-sig')

# %%
df_filter = df_merged[['Date', 'Time', 'InvoiceID']]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_filter = df_merged[['Date', 'Time', 'InvoiceID']]
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\frame.py:3773, in DataFrame.__getitem__(self, key)
#    3770 if getattr(indexer, "dtype", None) == bool:
#    3771     indexer = np.where(indexer)[0]
# -> 3773 data = self._take_with_is_copy(indexer, axis=1)
#    3775 if is_single_key:
#    3776     # What does looking for a single key in a non-unique index return?
#    3777     # The behavior is inconsistent. It returns a Series, except when
#    3778     # - the key itself is repeated (test on data.shape, #9519), or
#    3779     # - we have a MultiIndex on columns (test on self.columns, #21309)
#    3780     if data.shape[1] == 1 and not isinstance(self.columns, MultiIndex):
#    3781         # GH#26490 using data[key] can cause RecursionError
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\generic.py:3948, in NDFrame._take_with_is_copy(self, indices, axis)
#    3940 def _take_with_is_copy(self: NDFrameT, indices, axis: Axis = 0) -> NDFrameT:
#    3941     """
#    3942     Internal version of the `take` method that sets the `_is_copy`
#    3943     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3946     See the docstring of `take` for full explanation of the parameters.
#    3947     """
# -> 3948     result = self._take(indices=indices, axis=axis)
#    3949     # Maybe set copy if we didn't actually change the index.
#    3950     if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\generic.py:3932, in NDFrame._take(self, indices, axis, convert_indices)
#    3924     if (
#    3925         axis == 0
#    3926         and indices.ndim == 1
#    3927         and using_copy_on_write()
#    3928         and is_range_indexer(indices, len(self))
#    3929     ):
#    3930         return self.copy(deep=None)
# -> 3932 new_data = self._mgr.take(
#    3933     indices,
#    3934     axis=self._get_block_manager_axis(axis),
#    3935     verify=True,
#    3936     convert_indices=convert_indices,
#    3937 )
#    3938 return self._constructor(new_data).__finalize__(self, method="take")
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\internals\managers.py:963, in BaseBlockManager.take(self, indexer, axis, verify, convert_indices)
#     960     indexer = maybe_convert_indices(indexer, n, verify=verify)
#     962 new_labels = self.axes[axis].take(indexer)
# --> 963 return self.reindex_indexer(
#     964     new_axis=new_labels,
#     965     indexer=indexer,
#     966     axis=axis,
#     967     allow_dups=True,
#     968     copy=None,
#     969 )
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\internals\managers.py:740, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     737     raise IndexError("Requested axis not found in manager")
#     739 if axis == 0:
# --> 740     new_blocks = self._slice_take_blocks_ax0(
#     741         indexer,
#     742         fill_value=fill_value,
#     743         only_slice=only_slice,
#     744         use_na_proxy=use_na_proxy,
#     745     )
#     746 else:
#     747     new_blocks = [
#     748         blk.take_nd(
#     749             indexer,
#    (...)
#     755         for blk in self.blocks
#     756     ]
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\internals\managers.py:898, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy)
#     896                     blocks.append(nb)
#     897             else:
# --> 898                 nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     899                 blocks.append(nb)
#     901 return blocks
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\internals\blocks.py:945, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#     942     allow_fill = True
#     944 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# --> 945 new_values = algos.take_nd(
#     946     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#     947 )
#     949 # Called from three places in managers, all of which satisfy
#     950 #  these assertions
#     951 if isinstance(self, ExtensionBlock):
#     952     # NB: in this case, the 'axis' kwarg will be ignored in the
#     953     #  algos.take_nd call above.
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\trieu.pham\anaconda3\envs\myenv\Lib\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 822. MiB for an array with shape (3, 35898468) and data type object

# %%
# Merge the two dataframes on 'InvoiceID' and keep only 'Date' and 'Time' from df_merged
test_df = pd.merge(df_filter, group_by_invoice, on='InvoiceID', how='left')

print(test_df)
